# %%
import os

# %%
cpu_num = int(input("CPU 0 or 1? "))
if cpu_num != 0 and cpu_num != 1:
    print("invalid")
else: 
    # modified fib.py to optionally accept cmd line arg
    os.system(f"taskset -c {cpu_num} python3 fib.py 30")
# Out:
# CPU 0 or 1? 0
# time spent: 4.602286100387573
